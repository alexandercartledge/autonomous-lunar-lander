# %%
# x_change_training
# Cell 1

import gymnasium as gym
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize, VecMonitor
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.logger import TensorBoardOutputFormat
from stable_baselines3.common.utils import get_linear_fn
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize, VecMonitor
from statistics import mean, stdev
import pandas as pd
import time

# %% [markdown]
# Just pulling in Gym, NumPy, Stable‑Baselines3 and the SB3 helpers I’ll need. No logic yet, just getting tools ready

# %%
# Cell 2
# wrapper to extract custom metrics (fuel, landing error)
class LunarWrapper(gym.Wrapper):
    def reset(self, **kwargs):
        obs, info = super().reset(**kwargs)
        return obs, info

    def step(self, action):
        obs, reward, terminated, truncated, info = super().step(action)
        # approximate “fuel used”
        info["fuel_used"] = 1.0 if action == 2 else 0.0
        # landing error = distance from pad center
        info["landing_err"] = np.linalg.norm(obs[0:2])
        return obs, reward, terminated, truncated, info

# callback to log metrics to TensorBoard
class MetricsCallback(BaseCallback):
    def _on_training_start(self):
        if not any(isinstance(fmt, TensorBoardOutputFormat)
                   for fmt in self.logger.output_formats):
            self.logger.configure(format_strings=["tensorboard"])
    def _on_step(self) -> bool:
        for info in self.locals.get("infos", []):
            if "episode" in info:
                self.logger.record("custom/fuel_used",   info["fuel_used"])
                self.logger.record("custom/landing_err", info["landing_err"])
        return True

# build vec-env, monitor, normalize
def make_env():
    env = gym.make("LunarLander-v3")
    env = LunarWrapper(env)
    return env

env = DummyVecEnv([make_env])
# write one line per episode into monitor_04.csv
env = VecMonitor(env, filename="monitor_04.csv")
env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.0)

# instantiate PPO with fine-tuned hyperparameters
model = PPO(
    policy="MlpPolicy",
    env=env,
    tensorboard_log="./ppo_lunar_tb",
    verbose=1,
    n_steps=4096,
    batch_size=256,
    learning_rate=get_linear_fn(5e-4, 1e-5, 0.1),
    clip_range=0.15,
    ent_coef=0.005,
    policy_kwargs=dict(net_arch=[dict(pi=[128,128], vf=[128,128])]),
)

# train for 1 500 000 steps (to get score over 200), logging metrics 
model.learn(
    total_timesteps=1_500_000,
    callback=MetricsCallback(),
    tb_log_name="fine_tune"
)

# save final model and normalization stats
model.save("ppo_lunar_with_metrics")
env.save("ppo_vecnormalize.pkl")
print("Training complete and model saved.")
# Out:
# Using cpu device
# Logging to ./ppo_lunar_tb\fine_tune_10
# -----------------------------------
# | custom/            |            |
# |    fuel_used       | 0          |
# |    landing_err     | 0.42016345 |
# | rollout/           |            |
# |    ep_len_mean     | 94.4       |
# |    ep_rew_mean     | -162       |
# | time/              |            |
# |    fps             | 1388       |
# |    iterations      | 1          |
# |    time_elapsed    | 2          |
# |    total_timesteps | 4096       |
# -----------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.07190467   |
# | rollout/                |              |
# |    ep_len_mean          | 92.1         |
# |    ep_rew_mean          | -155         |
# | time/                   |              |
# |    fps                  | 1283         |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0043441057 |
# |    clip_fraction        | 0.0597       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.06        |
# |    learning_rate        | 0.000487     |
# |    loss                 | 0.109        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00682     |
# |    value_loss           | 0.62         |
# ------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.3186427    |
# | rollout/                |              |
# |    ep_len_mean          | 92           |
# |    ep_rew_mean          | -141         |
# | time/                   |              |
# |    fps                  | 1252         |
# |    iterations           | 3            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0062197293 |
# |    clip_fraction        | 0.108        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.48         |
# |    learning_rate        | 0.000473     |
# |    loss                 | 0.0637       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00806     |
# |    value_loss           | 0.247        |
# ------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.3838175    |
# | rollout/                |              |
# |    ep_len_mean          | 95.1         |
# |    ep_rew_mean          | -119         |
# | time/                   |              |
# |    fps                  | 1236         |
# |    iterations           | 4            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0066672144 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.58         |
# |    learning_rate        | 0.00046      |
# |    loss                 | 0.124        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00892     |
# |    value_loss           | 0.228        |
# ------------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    fuel_used            | 0           |
# |    landing_err          | 0.26184347  |
# | rollout/                |             |
# |    ep_len_mean          | 95          |
# |    ep_rew_mean          | -111        |
# | time/                   |             |
# |    fps                  | 1202        |
# |    iterations           | 5           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007394054 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.45        |
# |    learning_rate        | 0.000446    |
# |    loss                 | 0.0319      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 0.154       |
# -----------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    fuel_used            | 0           |
# |    landing_err          | 0.2695581   |
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 1195        |
# |    iterations           | 6           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.007995844 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.534       |
# |    learning_rate        | 0.000433    |
# |    loss                 | 0.0102      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 0.0899      |
# -----------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    fuel_used            | 1           |
# |    landing_err          | 0.43774176  |
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | -89.9       |
# | time/                   |             |
# |    fps                  | 1155        |
# |    iterations           | 7           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009164176 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.656       |
# |    learning_rate        | 0.00042     |
# |    loss                 | 0.0199      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 0.138       |
# -----------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    fuel_used            | 1           |
# |    landing_err          | 0.29925063  |
# | rollout/                |             |
# |    ep_len_mean          | 117         |
# |    ep_rew_mean          | -77.4       |
# | time/                   |             |
# |    fps                  | 1129        |
# |    iterations           | 8           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.013143506 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.789       |
# |    learning_rate        | 0.000406    |
# |    loss                 | -0.000479   |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 0.0658      |
# -----------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    fuel_used            | 0           |
# |    landing_err          | 0.6730331   |
# | rollout/                |             |
# |    ep_len_mean          | 124         |
# |    ep_rew_mean          | -67         |
# | time/                   |             |
# |    fps                  | 1115        |
# |    iterations           | 9           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007529366 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.753       |
# |    learning_rate        | 0.000393    |
# |    loss                 | 0.0185      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 0.0791      |
# -----------------------------------------
# ----------------------------------------
# | custom/                 |            |
# |    fuel_used            | 0          |
# |    landing_err          | 0.41938305 |
# | rollout/                |            |
# |    ep_len_mean          | 137        |
# |    ep_rew_mean          | -62.6      |
# | time/                   |            |
# |    fps                  | 1103       |
# |    iterations           | 10         |
# |    time_elapsed         | 37         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.00794408 |
# |    clip_fraction        | 0.218      |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -1.21      |
# |    explained_variance   | 0.906      |
# |    learning_rate        | 0.00038    |
# |    loss                 | -0.00689   |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0159    |
# |    value_loss           | 0.0442     |
# ----------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.20274535   |
# | rollout/                |              |
# |    ep_len_mean          | 145          |
# |    ep_rew_mean          | -58.4        |
# | time/                   |              |
# |    fps                  | 1095         |
# |    iterations           | 11           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0057775853 |
# |    clip_fraction        | 0.15         |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.918        |
# |    learning_rate        | 0.000366     |
# |    loss                 | -0.00333     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0117      |
# |    value_loss           | 0.0495       |
# ------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.46312115   |
# | rollout/                |              |
# |    ep_len_mean          | 156          |
# |    ep_rew_mean          | -52.5        |
# | time/                   |              |
# |    fps                  | 1086         |
# |    iterations           | 12           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0064268727 |
# |    clip_fraction        | 0.161        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.000353     |
# |    loss                 | 0.00452      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0135      |
# |    value_loss           | 0.0358       |
# ------------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    fuel_used            | 1           |
# |    landing_err          | 0.8782214   |
# | rollout/                |             |
# |    ep_len_mean          | 177         |
# |    ep_rew_mean          | -44.5       |
# | time/                   |             |
# |    fps                  | 1078        |
# |    iterations           | 13          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.008090673 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.000339    |
# |    loss                 | -0.0238     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 0.0319      |
# -----------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.05505286   |
# | rollout/                |              |
# |    ep_len_mean          | 203          |
# |    ep_rew_mean          | -48.8        |
# | time/                   |              |
# |    fps                  | 1071         |
# |    iterations           | 14           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0054888334 |
# |    clip_fraction        | 0.0851       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.957        |
# |    learning_rate        | 0.000326     |
# |    loss                 | -0.000957    |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00873     |
# |    value_loss           | 0.0372       |
# ------------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    fuel_used            | 0           |
# |    landing_err          | 0.23800875  |
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -44.6       |
# | time/                   |             |
# |    fps                  | 1058        |
# |    iterations           | 15          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.010037178 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.84        |
# |    learning_rate        | 0.000313    |
# |    loss                 | 0.0107      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 0.0894      |
# -----------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    fuel_used            | 0           |
# |    landing_err          | 0.18897851  |
# | rollout/                |             |
# |    ep_len_mean          | 260         |
# |    ep_rew_mean          | -40         |
# | time/                   |             |
# |    fps                  | 1054        |
# |    iterations           | 16          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008239193 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.000299    |
# |    loss                 | -0.00164    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00634    |
# |    value_loss           | 0.032       |
# -----------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    fuel_used            | 0           |
# |    landing_err          | 0.7945162   |
# | rollout/                |             |
# |    ep_len_mean          | 298         |
# |    ep_rew_mean          | -36.7       |
# | time/                   |             |
# |    fps                  | 1052        |
# |    iterations           | 17          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.006252138 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.000286    |
# |    loss                 | -0.0131     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00792    |
# |    value_loss           | 0.0389      |
# -----------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.35100138   |
# | rollout/                |              |
# |    ep_len_mean          | 319          |
# |    ep_rew_mean          | -34.7        |
# | time/                   |              |
# |    fps                  | 1049         |
# |    iterations           | 18           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0075981766 |
# |    clip_fraction        | 0.136        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.923        |
# |    learning_rate        | 0.000273     |
# |    loss                 | -0.00167     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00676     |
# |    value_loss           | 0.0418       |
# ------------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    fuel_used            | 0           |
# |    landing_err          | 0.3440669   |
# | rollout/                |             |
# |    ep_len_mean          | 355         |
# |    ep_rew_mean          | -29.5       |
# | time/                   |             |
# |    fps                  | 1036        |
# |    iterations           | 19          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.005901725 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.000259    |
# |    loss                 | -0.00408    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00737    |
# |    value_loss           | 0.0421      |
# -----------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.16689704   |
# | rollout/                |              |
# |    ep_len_mean          | 385          |
# |    ep_rew_mean          | -28.4        |
# | time/                   |              |
# |    fps                  | 1034         |
# |    iterations           | 20           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0038945926 |
# |    clip_fraction        | 0.046        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.881        |
# |    learning_rate        | 0.000246     |
# |    loss                 | 0.0319       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00349     |
# |    value_loss           | 0.0739       |
# ------------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    fuel_used            | 0           |
# |    landing_err          | 0.03834547  |
# | rollout/                |             |
# |    ep_len_mean          | 419         |
# |    ep_rew_mean          | -26.9       |
# | time/                   |             |
# |    fps                  | 1032        |
# |    iterations           | 21          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.006991578 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.000232    |
# |    loss                 | 0.00803     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00537    |
# |    value_loss           | 0.0457      |
# -----------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.3601151    |
# | rollout/                |              |
# |    ep_len_mean          | 458          |
# |    ep_rew_mean          | -23.3        |
# | time/                   |              |
# |    fps                  | 1032         |
# |    iterations           | 22           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0057754144 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.865        |
# |    learning_rate        | 0.000219     |
# |    loss                 | 0.00771      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00757     |
# |    value_loss           | 0.0632       |
# ------------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    fuel_used            | 0           |
# |    landing_err          | 0.3503739   |
# | rollout/                |             |
# |    ep_len_mean          | 482         |
# |    ep_rew_mean          | -21.6       |
# | time/                   |             |
# |    fps                  | 1031        |
# |    iterations           | 23          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.007572294 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.000206    |
# |    loss                 | -0.00109    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00792    |
# |    value_loss           | 0.036       |
# -----------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.09859123   |
# | rollout/                |              |
# |    ep_len_mean          | 521          |
# |    ep_rew_mean          | -18.5        |
# | time/                   |              |
# |    fps                  | 1031         |
# |    iterations           | 24           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0073607694 |
# |    clip_fraction        | 0.0846       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -0.962       |
# |    explained_variance   | 0.828        |
# |    learning_rate        | 0.000192     |
# |    loss                 | 0.0483       |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00628     |
# |    value_loss           | 0.111        |
# ------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.22995971   |
# | rollout/                |              |
# |    ep_len_mean          | 557          |
# |    ep_rew_mean          | -10.6        |
# | time/                   |              |
# |    fps                  | 1030         |
# |    iterations           | 25           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0056696218 |
# |    clip_fraction        | 0.0764       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.935        |
# |    learning_rate        | 0.000179     |
# |    loss                 | 0.00411      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00525     |
# |    value_loss           | 0.0243       |
# ------------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    fuel_used            | 0           |
# |    landing_err          | 0.44745886  |
# | rollout/                |             |
# |    ep_len_mean          | 587         |
# |    ep_rew_mean          | -8.16       |
# | time/                   |             |
# |    fps                  | 1031        |
# |    iterations           | 26          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.012172232 |
# |    clip_fraction        | 0.0987      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -0.863      |
# |    explained_variance   | 0.669       |
# |    learning_rate        | 0.000165    |
# |    loss                 | 0.0707      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00659    |
# |    value_loss           | 0.165       |
# -----------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    fuel_used            | 0           |
# |    landing_err          | 0.17144774  |
# | rollout/                |             |
# |    ep_len_mean          | 614         |
# |    ep_rew_mean          | -8.21       |
# | time/                   |             |
# |    fps                  | 1031        |
# |    iterations           | 27          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.006294105 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.000152    |
# |    loss                 | 0.00532     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00464    |
# |    value_loss           | 0.0381      |
# -----------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    fuel_used            | 0           |
# |    landing_err          | 0.54212606  |
# | rollout/                |             |
# |    ep_len_mean          | 649         |
# |    ep_rew_mean          | -3.57       |
# | time/                   |             |
# |    fps                  | 1032        |
# |    iterations           | 28          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.004590936 |
# |    clip_fraction        | 0.0694      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.781       |
# |    learning_rate        | 0.000139    |
# |    loss                 | 0.0219      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00287    |
# |    value_loss           | 0.113       |
# -----------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.4595262    |
# | rollout/                |              |
# |    ep_len_mean          | 672          |
# |    ep_rew_mean          | -3.16        |
# | time/                   |              |
# |    fps                  | 1032         |
# |    iterations           | 29           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0041635637 |
# |    clip_fraction        | 0.0729       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.86         |
# |    learning_rate        | 0.000125     |
# |    loss                 | 0.0161       |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00245     |
# |    value_loss           | 0.0516       |
# ------------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    fuel_used            | 0           |
# |    landing_err          | 0.2381581   |
# | rollout/                |             |
# |    ep_len_mean          | 704         |
# |    ep_rew_mean          | 1.11        |
# | time/                   |             |
# |    fps                  | 1032        |
# |    iterations           | 30          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.004656013 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -0.988      |
# |    explained_variance   | 0.816       |
# |    learning_rate        | 0.000112    |
# |    loss                 | 0.0792      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0042     |
# |    value_loss           | 0.122       |
# -----------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.3666623    |
# | rollout/                |              |
# |    ep_len_mean          | 714          |
# |    ep_rew_mean          | 8.64         |
# | time/                   |              |
# |    fps                  | 1030         |
# |    iterations           | 31           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 126976       |
# | train/                  |              |
# |    approx_kl            | 0.0030728842 |
# |    clip_fraction        | 0.0514       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -0.828       |
# |    explained_variance   | 0.841        |
# |    learning_rate        | 9.86e-05     |
# |    loss                 | 0.0283       |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.0027      |
# |    value_loss           | 0.122        |
# ------------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    fuel_used            | 0           |
# |    landing_err          | 0.41866148  |
# | rollout/                |             |
# |    ep_len_mean          | 737         |
# |    ep_rew_mean          | 20.7        |
# | time/                   |             |
# |    fps                  | 1027        |
# |    iterations           | 32          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.004040208 |
# |    clip_fraction        | 0.0502      |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.782       |
# |    learning_rate        | 8.52e-05    |
# |    loss                 | 0.0207      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00272    |
# |    value_loss           | 0.0836      |
# -----------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.16427693   |
# | rollout/                |              |
# |    ep_len_mean          | 737          |
# |    ep_rew_mean          | 24.3         |
# | time/                   |              |
# |    fps                  | 1028         |
# |    iterations           | 33           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 135168       |
# | train/                  |              |
# |    approx_kl            | 0.0055964775 |
# |    clip_fraction        | 0.126        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -0.976       |
# |    explained_variance   | 0.741        |
# |    learning_rate        | 7.18e-05     |
# |    loss                 | 0.089        |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00501     |
# |    value_loss           | 0.174        |
# ------------------------------------------
# ----------------------------------------
# | custom/                 |            |
# |    fuel_used            | 0          |
# |    landing_err          | 0.04356858 |
# | rollout/                |            |
# |    ep_len_mean          | 761        |
# |    ep_rew_mean          | 28.9       |
# | time/                   |            |
# |    fps                  | 1028       |
# |    iterations           | 34         |
# |    time_elapsed         | 135        |
# |    total_timesteps      | 139264     |
# | train/                  |            |
# |    approx_kl            | 0.00384737 |
# |    clip_fraction        | 0.0255     |
# |    clip_range           | 0.15       |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | 0.829      |
# |    learning_rate        | 5.85e-05   |
# |    loss                 | 0.016      |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.00266   |
# |    value_loss           | 0.0786     |
# ----------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.21481666   |
# | rollout/                |              |
# |    ep_len_mean          | 777          |
# |    ep_rew_mean          | 32.8         |
# | time/                   |              |
# |    fps                  | 1029         |
# |    iterations           | 35           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 143360       |
# | train/                  |              |
# |    approx_kl            | 0.0064418903 |
# |    clip_fraction        | 0.0691       |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.91         |
# |    learning_rate        | 4.51e-05     |
# |    loss                 | -0.00755     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00513     |
# |    value_loss           | 0.0295       |
# ------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.46888533   |
# | rollout/                |              |
# |    ep_len_mean          | 775          |
# |    ep_rew_mean          | 36.8         |
# | time/                   |              |
# |    fps                  | 1029         |
# |    iterations           | 36           |
# |    time_elapsed         | 143          |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0013946835 |
# |    clip_fraction        | 0.004        |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -0.939       |
# |    explained_variance   | 0.806        |
# |    learning_rate        | 3.17e-05     |
# |    loss                 | 0.0323       |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00143     |
# |    value_loss           | 0.0625       |
# ------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.32784557   |
# | rollout/                |              |
# |    ep_len_mean          | 793          |
# |    ep_rew_mean          | 46.6         |
# | time/                   |              |
# |    fps                  | 1029         |
# |    iterations           | 37           |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 151552       |
# | train/                  |              |
# |    approx_kl            | 0.0010905431 |
# |    clip_fraction        | 0.00413      |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -0.969       |
# |    explained_variance   | 0.873        |
# |    learning_rate        | 1.83e-05     |
# |    loss                 | 0.00899      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0013      |
# |    value_loss           | 0.0801       |
# ------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    fuel_used            | 0             |
# |    landing_err          | 0.08819045    |
# | rollout/                |               |
# |    ep_len_mean          | 806           |
# |    ep_rew_mean          | 49.6          |
# | time/                   |               |
# |    fps                  | 1029          |
# |    iterations           | 38            |
# |    time_elapsed         | 151           |
# |    total_timesteps      | 155648        |
# | train/                  |               |
# |    approx_kl            | 0.00042666006 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.15          |
# |    entropy_loss         | -0.922        |
# |    explained_variance   | 0.792         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 0.0654        |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -0.000384     |
# |    value_loss           | 0.133         |
# -------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.59621215   |
# | rollout/                |              |
# |    ep_len_mean          | 820          |
# |    ep_rew_mean          | 53.8         |
# | time/                   |              |
# |    fps                  | 1029         |
# |    iterations           | 39           |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 159744       |
# | train/                  |              |
# |    approx_kl            | 0.0004444116 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.866        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.00817      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00072     |
# |    value_loss           | 0.0551       |
# ------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    fuel_used            | 0             |
# |    landing_err          | 0.35152367    |
# | rollout/                |               |
# |    ep_len_mean          | 824           |
# |    ep_rew_mean          | 58            |
# | time/                   |               |
# |    fps                  | 1029          |
# |    iterations           | 40            |
# |    time_elapsed         | 159           |
# |    total_timesteps      | 163840        |
# | train/                  |               |
# |    approx_kl            | 0.00053271645 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.15          |
# |    entropy_loss         | -0.931        |
# |    explained_variance   | 0.802         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 0.0143        |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000588     |
# |    value_loss           | 0.0995        |
# -------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.59825194   |
# | rollout/                |              |
# |    ep_len_mean          | 820          |
# |    ep_rew_mean          | 63.9         |
# | time/                   |              |
# |    fps                  | 1027         |
# |    iterations           | 41           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0009394841 |
# |    clip_fraction        | 0.000122     |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.897        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.00447      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 0.0309       |
# ------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    fuel_used            | 0             |
# |    landing_err          | 0.4508802     |
# | rollout/                |               |
# |    ep_len_mean          | 817           |
# |    ep_rew_mean          | 70.2          |
# | time/                   |               |
# |    fps                  | 1025          |
# |    iterations           | 42            |
# |    time_elapsed         | 167           |
# |    total_timesteps      | 172032        |
# | train/                  |               |
# |    approx_kl            | 0.00019021655 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.15          |
# |    entropy_loss         | -0.984        |
# |    explained_variance   | 0.813         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 0.0712        |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000203     |
# |    value_loss           | 0.102         |
# -------------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    fuel_used            | 0           |
# |    landing_err          | 0.14543888  |
# | rollout/                |             |
# |    ep_len_mean          | 826         |
# |    ep_rew_mean          | 75.3        |
# | time/                   |             |
# |    fps                  | 1025        |
# |    iterations           | 43          |
# |    time_elapsed         | 171         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.000310063 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -0.973      |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0109      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.000527   |
# |    value_loss           | 0.0548      |
# -----------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    fuel_used            | 0             |
# |    landing_err          | 0.026994271   |
# | rollout/                |               |
# |    ep_len_mean          | 826           |
# |    ep_rew_mean          | 78.4          |
# | time/                   |               |
# |    fps                  | 1027          |
# |    iterations           | 44            |
# |    time_elapsed         | 175           |
# |    total_timesteps      | 180224        |
# | train/                  |               |
# |    approx_kl            | 0.00045198845 |
# |    clip_fraction        | 0.000171      |
# |    clip_range           | 0.15          |
# |    entropy_loss         | -0.9          |
# |    explained_variance   | 0.86          |
# |    learning_rate        | 1e-05         |
# |    loss                 | 0.0203        |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.000655     |
# |    value_loss           | 0.0678        |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    fuel_used            | 0             |
# |    landing_err          | 0.41553205    |
# | rollout/                |               |
# |    ep_len_mean          | 813           |
# |    ep_rew_mean          | 79.4          |
# | time/                   |               |
# |    fps                  | 1025          |
# |    iterations           | 45            |
# |    time_elapsed         | 179           |
# |    total_timesteps      | 184320        |
# | train/                  |               |
# |    approx_kl            | 0.00026829925 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.15          |
# |    entropy_loss         | -1.02         |
# |    explained_variance   | 0.871         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 0.0291        |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000628     |
# |    value_loss           | 0.0592        |
# -------------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    fuel_used            | 0           |
# |    landing_err          | 0.17281745  |
# | rollout/                |             |
# |    ep_len_mean          | 813         |
# |    ep_rew_mean          | 83.5        |
# | time/                   |             |
# |    fps                  | 1024        |
# |    iterations           | 46          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.000336079 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -0.921      |
# |    explained_variance   | 0.774       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0477      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00052    |
# |    value_loss           | 0.183       |
# -----------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.15657063   |
# | rollout/                |              |
# |    ep_len_mean          | 819          |
# |    ep_rew_mean          | 89.1         |
# | time/                   |              |
# |    fps                  | 1025         |
# |    iterations           | 47           |
# |    time_elapsed         | 187          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0015242745 |
# |    clip_fraction        | 0.000635     |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -0.962       |
# |    explained_variance   | 0.754        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.0406       |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00182     |
# |    value_loss           | 0.0889       |
# ------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.49115092   |
# | rollout/                |              |
# |    ep_len_mean          | 798          |
# |    ep_rew_mean          | 98.1         |
# | time/                   |              |
# |    fps                  | 1026         |
# |    iterations           | 48           |
# ...
# |    explained_variance   | 0.954         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 0.019         |
# |    n_updates            | 3510          |
# |    policy_gradient_loss | -0.000263     |
# |    value_loss           | 0.0633        |
# -------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.821444     |
# | rollout/                |              |
# |    ep_len_mean          | 668          |
# |    ep_rew_mean          | 158          |
# | time/                   |              |
# |    fps                  | 990          |
# |    iterations           | 353          |
# |    time_elapsed         | 1460         |
# |    total_timesteps      | 1445888      |
# | train/                  |              |
# |    approx_kl            | 0.0005470485 |
# |    clip_fraction        | 0.00249      |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -0.77        |
# |    explained_variance   | 0.859        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.0948       |
# |    n_updates            | 3520         |
# |    policy_gradient_loss | -0.000849    |
# |    value_loss           | 0.176        |
# ------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    fuel_used            | 0             |
# |    landing_err          | 0.15926158    |
# | rollout/                |               |
# |    ep_len_mean          | 666           |
# |    ep_rew_mean          | 160           |
# | time/                   |               |
# |    fps                  | 990           |
# |    iterations           | 354           |
# |    time_elapsed         | 1463          |
# |    total_timesteps      | 1449984       |
# | train/                  |               |
# |    approx_kl            | 0.00025876454 |
# |    clip_fraction        | 0.000122      |
# |    clip_range           | 0.15          |
# |    entropy_loss         | -0.664        |
# |    explained_variance   | 0.89          |
# |    learning_rate        | 1e-05         |
# |    loss                 | 0.0921        |
# |    n_updates            | 3530          |
# |    policy_gradient_loss | -0.00071      |
# |    value_loss           | 0.171         |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    fuel_used            | 1             |
# |    landing_err          | 0.5741235     |
# | rollout/                |               |
# |    ep_len_mean          | 596           |
# |    ep_rew_mean          | 159           |
# | time/                   |               |
# |    fps                  | 990           |
# |    iterations           | 355           |
# |    time_elapsed         | 1467          |
# |    total_timesteps      | 1454080       |
# | train/                  |               |
# |    approx_kl            | 0.00060277915 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.15          |
# |    entropy_loss         | -0.673        |
# |    explained_variance   | 0.883         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 0.14          |
# |    n_updates            | 3540          |
# |    policy_gradient_loss | -0.000613     |
# |    value_loss           | 0.172         |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    fuel_used            | 0             |
# |    landing_err          | 0.25279784    |
# | rollout/                |               |
# |    ep_len_mean          | 588           |
# |    ep_rew_mean          | 156           |
# | time/                   |               |
# |    fps                  | 990           |
# |    iterations           | 356           |
# |    time_elapsed         | 1471          |
# |    total_timesteps      | 1458176       |
# | train/                  |               |
# |    approx_kl            | 0.00028059096 |
# |    clip_fraction        | 2.44e-05      |
# |    clip_range           | 0.15          |
# |    entropy_loss         | -0.706        |
# |    explained_variance   | 0.808         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 0.307         |
# |    n_updates            | 3550          |
# |    policy_gradient_loss | -0.000829     |
# |    value_loss           | 0.414         |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    fuel_used            | 0             |
# |    landing_err          | 0.30331597    |
# | rollout/                |               |
# |    ep_len_mean          | 589           |
# |    ep_rew_mean          | 156           |
# | time/                   |               |
# |    fps                  | 990           |
# |    iterations           | 357           |
# |    time_elapsed         | 1475          |
# |    total_timesteps      | 1462272       |
# | train/                  |               |
# |    approx_kl            | 0.00047088735 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.15          |
# |    entropy_loss         | -0.769        |
# |    explained_variance   | 0.931         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 0.0718        |
# |    n_updates            | 3560          |
# |    policy_gradient_loss | -0.000678     |
# |    value_loss           | 0.134         |
# -------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.33181098   |
# | rollout/                |              |
# |    ep_len_mean          | 590          |
# |    ep_rew_mean          | 161          |
# | time/                   |              |
# |    fps                  | 990          |
# |    iterations           | 358          |
# |    time_elapsed         | 1479         |
# |    total_timesteps      | 1466368      |
# | train/                  |              |
# |    approx_kl            | 0.0005341446 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -0.751       |
# |    explained_variance   | 0.953        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.0244       |
# |    n_updates            | 3570         |
# |    policy_gradient_loss | -0.000584    |
# |    value_loss           | 0.0655       |
# ------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    fuel_used            | 0             |
# |    landing_err          | 0.028497728   |
# | rollout/                |               |
# |    ep_len_mean          | 582           |
# |    ep_rew_mean          | 160           |
# | time/                   |               |
# |    fps                  | 991           |
# |    iterations           | 359           |
# |    time_elapsed         | 1483          |
# |    total_timesteps      | 1470464       |
# | train/                  |               |
# |    approx_kl            | 0.00050806056 |
# |    clip_fraction        | 0.00134       |
# |    clip_range           | 0.15          |
# |    entropy_loss         | -0.715        |
# |    explained_variance   | 0.904         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 0.0325        |
# |    n_updates            | 3580          |
# |    policy_gradient_loss | -0.00158      |
# |    value_loss           | 0.147         |
# -------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.015419137  |
# | rollout/                |              |
# |    ep_len_mean          | 583          |
# |    ep_rew_mean          | 162          |
# | time/                   |              |
# |    fps                  | 991          |
# |    iterations           | 360          |
# |    time_elapsed         | 1487         |
# |    total_timesteps      | 1474560      |
# | train/                  |              |
# |    approx_kl            | 0.0008357981 |
# |    clip_fraction        | 0.00298      |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -0.804       |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.0114       |
# |    n_updates            | 3590         |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 0.0542       |
# ------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.19533911   |
# | rollout/                |              |
# |    ep_len_mean          | 576          |
# |    ep_rew_mean          | 166          |
# | time/                   |              |
# |    fps                  | 991          |
# |    iterations           | 361          |
# |    time_elapsed         | 1491         |
# |    total_timesteps      | 1478656      |
# | train/                  |              |
# |    approx_kl            | 0.0006767085 |
# |    clip_fraction        | 0.000171     |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -0.752       |
# |    explained_variance   | 0.928        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.0462       |
# |    n_updates            | 3600         |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 0.0917       |
# ------------------------------------------
# -----------------------------------------
# | custom/                 |             |
# |    fuel_used            | 0           |
# |    landing_err          | 0.05653127  |
# | rollout/                |             |
# |    ep_len_mean          | 573         |
# |    ep_rew_mean          | 167         |
# | time/                   |             |
# |    fps                  | 991         |
# |    iterations           | 362         |
# |    time_elapsed         | 1495        |
# |    total_timesteps      | 1482752     |
# | train/                  |             |
# |    approx_kl            | 0.000615375 |
# |    clip_fraction        | 0.000171    |
# |    clip_range           | 0.15        |
# |    entropy_loss         | -0.725      |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0479      |
# |    n_updates            | 3610        |
# |    policy_gradient_loss | -0.00103    |
# |    value_loss           | 0.149       |
# -----------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.5246614    |
# | rollout/                |              |
# |    ep_len_mean          | 588          |
# |    ep_rew_mean          | 168          |
# | time/                   |              |
# |    fps                  | 991          |
# |    iterations           | 363          |
# |    time_elapsed         | 1499         |
# |    total_timesteps      | 1486848      |
# | train/                  |              |
# |    approx_kl            | 0.0021390067 |
# |    clip_fraction        | 0.00186      |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -0.661       |
# |    explained_variance   | 0.933        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.00885      |
# |    n_updates            | 3620         |
# |    policy_gradient_loss | -0.00147     |
# |    value_loss           | 0.073        |
# ------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    fuel_used            | 0             |
# |    landing_err          | 0.04327576    |
# | rollout/                |               |
# |    ep_len_mean          | 578           |
# |    ep_rew_mean          | 167           |
# | time/                   |               |
# |    fps                  | 991           |
# |    iterations           | 364           |
# |    time_elapsed         | 1503          |
# |    total_timesteps      | 1490944       |
# | train/                  |               |
# |    approx_kl            | 0.00040986744 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.15          |
# |    entropy_loss         | -0.652        |
# |    explained_variance   | 0.959         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 0.00692       |
# |    n_updates            | 3630          |
# |    policy_gradient_loss | -0.000588     |
# |    value_loss           | 0.0305        |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    fuel_used            | 0             |
# |    landing_err          | 0.021576004   |
# | rollout/                |               |
# |    ep_len_mean          | 575           |
# |    ep_rew_mean          | 166           |
# | time/                   |               |
# |    fps                  | 991           |
# |    iterations           | 365           |
# |    time_elapsed         | 1507          |
# |    total_timesteps      | 1495040       |
# | train/                  |               |
# |    approx_kl            | 0.00047750038 |
# |    clip_fraction        | 0.000171      |
# |    clip_range           | 0.15          |
# |    entropy_loss         | -0.683        |
# |    explained_variance   | 0.899         |
# |    learning_rate        | 1e-05         |
# |    loss                 | 0.0636        |
# |    n_updates            | 3640          |
# |    policy_gradient_loss | -0.00106      |
# |    value_loss           | 0.167         |
# -------------------------------------------
# -------------------------------------------
# | custom/                 |               |
# |    fuel_used            | 0             |
# |    landing_err          | 0.09796166    |
# | rollout/                |               |
# |    ep_len_mean          | 589           |
# |    ep_rew_mean          | 167           |
# | time/                   |               |
# |    fps                  | 991           |
# |    iterations           | 366           |
# |    time_elapsed         | 1511          |
# |    total_timesteps      | 1499136       |
# | train/                  |               |
# |    approx_kl            | 0.00032133216 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.15          |
# |    entropy_loss         | -0.73         |
# |    explained_variance   | 0.971         |
# |    learning_rate        | 1e-05         |
# |    loss                 | -0.00243      |
# |    n_updates            | 3650          |
# |    policy_gradient_loss | -0.00071      |
# |    value_loss           | 0.043         |
# -------------------------------------------
# ------------------------------------------
# | custom/                 |              |
# |    fuel_used            | 0            |
# |    landing_err          | 0.2430893    |
# | rollout/                |              |
# |    ep_len_mean          | 590          |
# |    ep_rew_mean          | 166          |
# | time/                   |              |
# |    fps                  | 991          |
# |    iterations           | 367          |
# |    time_elapsed         | 1515         |
# |    total_timesteps      | 1503232      |
# | train/                  |              |
# |    approx_kl            | 0.0021221454 |
# |    clip_fraction        | 0.000952     |
# |    clip_range           | 0.15         |
# |    entropy_loss         | -0.675       |
# |    explained_variance   | 0.949        |
# |    learning_rate        | 1e-05        |
# |    loss                 | -0.003       |
# |    n_updates            | 3660         |
# |    policy_gradient_loss | -0.00184     |
# |    value_loss           | 0.0465       |
# ------------------------------------------
# Training complete and model saved.

# %% [markdown]
# I wrap the env to log fuel and landing error, vectorize/monitor/normalize it, pick my PPO hyperparameters, then run 1.5 M training steps (just manages to reach reward of 200, which is what is classified as a success). Finally I save the model and normalization stats.

# %%
# Cell 3: Playback to confirm random‐start

# copy wrappers from Cell 1, but make reset return (obs, info)
class RandomStartWrapper(gym.Wrapper):
    def reset(self, **kwargs):
        obs, info = super().reset(**kwargs)
        # pick and apply world shift
        self.pad_shift = self.np_random.uniform(-1.0, 1.0)
        uw = self.unwrapped
        uw.helipad_x1 += self.pad_shift
        uw.helipad_x2 += self.pad_shift
        obs = obs.copy(); obs[0] -= self.pad_shift
        return obs, info   # ← two values

    def step(self, action):
        obs, reward, terminated, truncated, info = super().step(action)
        obs = obs.copy(); obs[0] -= self.pad_shift
        return obs, reward, terminated, truncated, info

class LunarWrapper(gym.Wrapper):
    def reset(self, **kwargs):
        return super().reset(**kwargs)    # ← passes through (obs, info)
    def step(self, action):
        obs, reward, term, trunc, info = super().step(action)
        info["fuel_used"] = 1.0 if action==2 else 0.0
        return obs, reward, term, trunc, info

def play_back(model_path, n_steps=500, sleep=0.016):
    def make_env():
        e = gym.make("LunarLander-v3", render_mode="human")
        e = RandomStartWrapper(e)
        e = LunarWrapper(e)
        return e

    ev = DummyVecEnv([make_env])
    ev = VecMonitor(ev)  
    ev = VecNormalize.load("ppo_vecnormalize.pkl", ev)
    ev.training=False; ev.norm_reward=False

    m = PPO.load(model_path, env=ev)
    obs = ev.reset()               # ← unpack (obs, infos)
    for i in range(n_steps):
        action, i = m.predict(obs, deterministic=True)
        obs, i, dones, i = ev.step(action)
        ev.render()
        time.sleep(sleep)
        if dones[0]:
            break
    ev.close()

print("Playback random‐start policy:")
play_back("ppo_lunar_with_metrics.zip")
# Out:
# Playback random‐start policy:

# %% [markdown]
# Reload the saved policy, rebuild the same normalization pipeline, and render up to 500 frames in human mode so you can see the agent actually land.

# %%
# Cell 4
class RandomPadWrapper(gym.Wrapper):
    def reset(self, **kwargs):
        obs, info = super().reset(**kwargs)
        # pick random shift Δ
        self.pad_shift = self.np_random.uniform(-0.4, 0.4)
        # move the pad flags in the unwrapped env
        uw = self.unwrapped
        uw.helipad_x1 += self.pad_shift
        uw.helipad_x2 += self.pad_shift
        # shift obs so agent still sees pad at 0
        obs = obs.copy()
        obs[0] -= self.pad_shift
        return obs, info

    def step(self, action):
        obs, reward, terminated, truncated, info = super().step(action)
        obs = obs.copy()
        obs[0] -= self.pad_shift
        return obs, reward, terminated, truncated, info

# %% [markdown]
# Here’s a little class that on each reset randomly shifts the pad’s world‑x by ±0.4, while keeping the agent’s observation centered at x = 0.

# %%
# Cell 5: Quantitative evaluation + CSV export

# bring in LunarWrapper so reset returns (obs, info) and step adds fuel_used
class LunarWrapper(gym.Wrapper):
    def reset(self, **kwargs):
        obs, info = super().reset(**kwargs)
        return obs, info
    def step(self, action):
        obs, reward, term, trunc, info = super().step(action)
        info["fuel_used"] = 1.0 if action == 2 else 0.0
        return obs, reward, term, trunc, info

def make_eval_env():
    e = gym.make("LunarLander-v3")
    e = RandomPadWrapper(e)   # shift the pad
    e = LunarWrapper(e)       # now track fuel_used
    return e                  # ← return that wrapped env

# build vec‑env & load normalization
eval_env = DummyVecEnv([make_eval_env])
eval_env = VecMonitor(eval_env)
eval_env = VecNormalize.load("ppo_vecnormalize.pkl", eval_env)
eval_env.training = False
eval_env.norm_reward = False

# load model
model = PPO.load("ppo_lunar_with_metrics.zip", env=eval_env)

# evaluation loop
def evaluate(model, env, n_episodes=50):
    rewards, fuels, successes = [], [], 0
    for i in range(n_episodes):
        obs = env.reset()       # ← only one return value now
        done = False
        R, F = 0.0, 0.0
        while not done:
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, dones, infos = env.step(action)
            R += reward[0]
            F += infos[0]["fuel_used"]
            done = dones[0]
        rewards.append(R)
        fuels.append(F)
        if R >= 200:
            successes += 1
    return rewards, fuels, successes

# run and report
rewards, fuels, successes = evaluate(model, eval_env, n_episodes=50)
mean_r, mean_f = mean(rewards), mean(fuels)
succ_rate = successes / 50

print(f"Mean reward:    {mean_r:.1f} ± {stdev(rewards):.1f}")
print(f"Mean fuel used: {mean_f:.1f} ± {stdev(fuels):.1f}")
print(f"Success rate:   {successes}/50 = {succ_rate:.0%}")

# ── write out metrics for bar chart ──
df = pd.DataFrame([{
    "experiment":   "ppo_x_change",
    "mean_reward":  mean_r,
    "mean_fuel":    mean_f,
    "success_rate": succ_rate
}])
df.to_csv("04_x_change_metrics.csv", index=False)
print("→ metrics written to 04_x_change_metrics.csv")
# Out:
# Mean reward:    195.4 ± 84.3
# Mean fuel used: 124.2 ± 22.5
# Success rate:   35/50 = 70%
# → metrics written to 04_x_change_metrics.csv

# %% [markdown]
# Now I combine the fuel‑logger and random‑pad wrappers, load the fixed‑pad policy, and run 50 episodes, printing mean reward and mean fuel so I can see how well the policy generalizes.
